# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import  accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
data = pd.read_csv("Data\Classification\Drug.csv")

# %%
X=data.drop(columns='Drug')
y=data['Drug']

# %%
X=pd.get_dummies(X,dtype=float,drop_first=True)
X

# %% [markdown]
# **Have them fill in**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size='?????', random_state='?????')

# %% [markdown]
# **Have them complete the parameter dictionary**

# %%
knn = KNeighborsClassifier()
# Parameter tuning with GridSearchCV
param_knn = {
    'n_neighbors': list(range('?????', '?????')),
    'p': ('?????', '?????'),
    'weights': ('?????', '?????''?????'),
    'metric': ('?????''?????', '?????''?????''?????')
}

# %%
# Fitting the model for GridSearchCV
grid_search_knn = GridSearchCV(knn, param_knn, cv=10, n_jobs=-1, scoring='accuracy')
grid_search_knn.fit(X_train, y_train)
# Best parameters for KNN
grid_search_knn.best_params_

# %% [markdown]
# **Have them fill in the optimal parameters from GridSearchCV**

# %%
# Fitting KNN with the best parameters
knn = KNeighborsClassifier(n_neighbors='?????', metric='?????', p='?????', weights='?????')
knn.'??????'(X_train, y_train)

# %% [markdown]
# **Have them fill in**

# %%
y_pred = knn.predict(X_test)
accuracy = '????????'(y_test, y_pred) * 100
accuracy
